# %%
from lxml import html
import requests

# %%
page = requests.get('https://fairygodboss.com/maternity-leave-resource-center?page=100')
tree = html.fromstring(page.content)

# %%
print(tree)
# Out:
# <Element html at 0x10344d728>

# %%
print(html.tostring(tree))
# Out:
# b'<html lang="en">\n<head prefix="og: http://ogp.me/ns#">\n            <!-- Global site tag (gtag.js) - Google Analytics -->\n        <script async src="https://www.googletagmanager.com/gtag/js?id=UA-52626819-1"></script>\n        <script>\n            window.dataLayer = window.dataLayer || [];\n            function gtag(){dataLayer.push(arguments);}\n            gtag(\'js\', new Date());\n\n            gtag(\'config\', \'UA-52626819-1\');\n\n        </script>\n\n    \n    \n\n    \n\n    <script type="text/javascript">\n        externalPageProps = {\n            headerProps: {"commonProps":{"role":null,"isAdmin":false,"fairygodbossUrl":"\\/","currentUrl":"\\/maternity-leave-resource-center?page=100","showTopSearchBar":true,"showSearchForm":true,"menuUrls":[{"name":"companies","url":"\\/company-overview","subMenus":null},{"name":"jobs","url":"\\/jobs\\/filter","subMenus":null},{"name":"company reviews","url":"\\/company-reviews","subtopMenus":null},{"name":"salaries","url":"\\/salary-database","subMenus":null},{"name":"maternity","url":"\\/maternity-leave","subMenus":[{"name":"maternity leave","url":"\\/maternity-leave"},{"name":"pregnancy week by week","url":"\\/pregnancy-week-by-week"}]},{"name":"work-life balance","url":"\\/work-life-balance-flexibility-guide","subMenus":null},{"name":"career advice","url":"\\/articles","subMenus":[{"name":"recent articles","url":"\\/articles"},{"name":"career topics","url":"\\/career-topics"},{"name":"podcasts","url":"community-podcasts"},{"name":"research from fairygodboss","url":"\\/research"},{"name":"research from third parties","url":"\\/third-party-research"}]},{"name":"New Today","url":"\\/community\\/feed","subMenus":null,"featuredStyling":"featured"},{"name":"top rated","url":"\\/best-companies-for-women","subMenus":[{"name":"best tech","url":"\\/best-companies-for-women-technology"},{"name":"best finance","url":"\\/best-companies-for-women-finance"},{"name":"best company CEOs","url":"\\/best-companies-for-women-gender-diversity"},{"name":"best 2018","url":"\\/best-companies-for-women-2018"}]}],"mobileMenuUrls":[{"name":"Jobs","url":"\\/jobs\\/filter"},{"name":"Advice","url":"\\/articles"},{"name":"Job Reviews","url":"\\/company-reviews"},{"name":"New Today","url":"\\/community\\/feed","featuredStyling":"featured"}]},"adminProps":{"adminLinks":[{"name":"add company","url":"\\/admins\\/add-company","authorizedRoles":["superadmin","fullEditor","sales","customerSuccess"]},{"name":"companies list","url":"\\/admins\\/companies","authorizedRoles":["superadmin","customerSuccess"]},{"name":"inactive companies","url":"\\/admins\\/inactive-companies","authorizedRoles":["superadmin"]},{"name":"user submitted data","url":"\\/admins\\/user-submitted-data","authorizedRoles":["superadmin"]},{"name":"search user","url":"\\/admins\\/user-search","authorizedRoles":["superadmin"]},{"name":"top of 2015","url":"\\/admins\\/top-companies-of2015","authorizedRoles":["superadmin","customerSuccess"]},{"name":"top of 2016","url":"\\/admins\\/top-companies-of2016","authorizedRoles":["superadmin","customerSuccess"]},{"name":"top of 2017 by quarters","url":"\\/admins\\/best-companies-by-quarter","authorizedRoles":["superadmin","customerSuccess"]},{"name":"salaries","url":"\\/admins\\/salaries","authorizedRoles":["superadmin"]},{"name":"export maternity db","url":"\\/exports\\/maternetyleave","authorizedRoles":["superadmin"]},{"name":"export maternity db(by Industry)","url":"\\/exports\\/maternetyleavebyindustry","authorizedRoles":["superadmin"]},{"name":"export maternity db(by Top Industry)","url":"\\/exports\\/maternety-leave-by-top-industry","authorizedRoles":["superadmin"]},{"name":"tags bank","url":"\\/admins\\/tags-bank","authorizedRoles":["superadmin","fullEditor"]},{"name":"benefit comments","url":"\\/admins\\/benefit-comments","authorizedRoles":["superadmin"]},{"name":"employer request","url":"\\/admins\\/employer-requests","authorizedRoles":["superadmin","sales","customerSuccess"]},{"name":"employer q ...

# %%
rows = tree.xpath('//tr')

# %%
# Remove white space
companies = rows[0].xpath('//td/text()')

split_companies = []

for x in companies:
    split_companies.append(x.split())
    
print(split_companies)
# Out:
# [['Avalex', 'Technologies'], ['Aerospace'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], [], ['Media', 'Assembly'], ['Advertising'], ['N/A'], ['N/A'], ['2'], ['N/A'], [], [], ['Castleton', 'Commodities', 'International'], ['Finance:', 'Diversified'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], [], ['CARE', 'International'], ['Nonprofit:', 'Humanitarian', 'Aid', 'Organization'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], [], ['WinCo', 'Foods'], ['Retail:', 'Supermarket', 'Company'], ['N/A'], ['N/A'], ['12'], ['N/A'], [], [], ['Princess', 'Cruises'], ['Leisure,', 'Travel', '&', 'Tourism'], ['N/A'], ['18'], ['N/A'], ['N/A'], [], [], ['Oak', 'Ridge', 'National', 'Laboratory'], ['Government:', 'Federal'], ['N/A'], ['N/A'], ['1'], ['N/A'], [], [], ['Black', 'Twig', 'Communications'], ['Public', 'Relations'], ['N/A'], ['0'], ['N/A'], ['N/A'], [], [], ['Midcontinent'], ['Telecommunications'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], [], ['Hanesbrands', 'Inc'], ['Retail:', 'Shoes,', 'Accessories', 'and', 'Apparel'], ['N/A'], ['N/A'], ['0'], ['N/A'], [], [], ['American', 'Medical', 'Association'], ['Nonprofit:', 'Medical'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], [], ['SCANA', 'Corporation'], ['Natural', 'Resources:', 'Electric', '&', 'Gas', 'Utilit...'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], [], ['ManTech', 'International'], ['Technology:', 'B2B', 'Tech', 'Services'], ['N/A'], ['0'], ['0'], ['0'], [], [], ['Aspen', 'Dental'], ['Healthcare:', 'Services'], ['N/A'], ['6'], ['N/A'], ['N/A'], [], [], ['BAUER', 'Hockey,', 'Inc'], ['Sporting', 'Goods'], ['N/A'], ['2'], ['N/A'], ['N/A'], [], [], ['1199SEIU'], ['Nonprofit:', 'Healthcare'], ['N/A'], ['N/A'], ['26'], ['N/A'], [], [], ['Ex', 'Libris', 'Group'], ['Technology:', 'Software'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], [], ['Clark', 'Construction', 'Group'], ['Industrial:', 'Construction', 'Company'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], [], ['BJs', 'Wholesale', 'Club'], ['Retail:', 'Discount', 'Store'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], [], ['Finning', 'International', 'Inc.'], ['Industrial:', 'Equipment', 'Manufacturing'], ['N/A'], ['N/A'], ['12'], ['N/A'], [], []]

# %%
# Each row is 8 cells long, so split by 8
separated_companies = []
one_company = []

counter = 0
for x in split_companies:
    one_company.append(x)
    counter+=1
    if counter == 8:
        separated_companies.append(one_company)
        one_company = []
        counter = 0

for x in separated_companies:
    print(x)
# Out:
# [['Avalex', 'Technologies'], ['Aerospace'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], []]
# [['Media', 'Assembly'], ['Advertising'], ['N/A'], ['N/A'], ['2'], ['N/A'], [], []]
# [['Castleton', 'Commodities', 'International'], ['Finance:', 'Diversified'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], []]
# [['CARE', 'International'], ['Nonprofit:', 'Humanitarian', 'Aid', 'Organization'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], []]
# [['WinCo', 'Foods'], ['Retail:', 'Supermarket', 'Company'], ['N/A'], ['N/A'], ['12'], ['N/A'], [], []]
# [['Princess', 'Cruises'], ['Leisure,', 'Travel', '&', 'Tourism'], ['N/A'], ['18'], ['N/A'], ['N/A'], [], []]
# [['Oak', 'Ridge', 'National', 'Laboratory'], ['Government:', 'Federal'], ['N/A'], ['N/A'], ['1'], ['N/A'], [], []]
# [['Black', 'Twig', 'Communications'], ['Public', 'Relations'], ['N/A'], ['0'], ['N/A'], ['N/A'], [], []]
# [['Midcontinent'], ['Telecommunications'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], []]
# [['Hanesbrands', 'Inc'], ['Retail:', 'Shoes,', 'Accessories', 'and', 'Apparel'], ['N/A'], ['N/A'], ['0'], ['N/A'], [], []]
# [['American', 'Medical', 'Association'], ['Nonprofit:', 'Medical'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], []]
# [['SCANA', 'Corporation'], ['Natural', 'Resources:', 'Electric', '&', 'Gas', 'Utilit...'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], []]
# [['ManTech', 'International'], ['Technology:', 'B2B', 'Tech', 'Services'], ['N/A'], ['0'], ['0'], ['0'], [], []]
# [['Aspen', 'Dental'], ['Healthcare:', 'Services'], ['N/A'], ['6'], ['N/A'], ['N/A'], [], []]
# [['BAUER', 'Hockey,', 'Inc'], ['Sporting', 'Goods'], ['N/A'], ['2'], ['N/A'], ['N/A'], [], []]
# [['1199SEIU'], ['Nonprofit:', 'Healthcare'], ['N/A'], ['N/A'], ['26'], ['N/A'], [], []]
# [['Ex', 'Libris', 'Group'], ['Technology:', 'Software'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], []]
# [['Clark', 'Construction', 'Group'], ['Industrial:', 'Construction', 'Company'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], []]
# [['BJs', 'Wholesale', 'Club'], ['Retail:', 'Discount', 'Store'], ['N/A'], ['12'], ['N/A'], ['N/A'], [], []]
# [['Finning', 'International', 'Inc.'], ['Industrial:', 'Equipment', 'Manufacturing'], ['N/A'], ['N/A'], ['12'], ['N/A'], [], []]

# %%
def objectCompany(n): 
    return {'Company': ' '.join(n[0]), 'Industry': ' '.join(n[1]), 'MaternityLeave': n[2][0]}

# Organize elements into a dictionary
organized_companies = map(objectCompany, separated_companies)

print(list(organized_companies))
# Out:
# [{'Company': 'Avalex Technologies', 'Industry': 'Aerospace', 'MaternityLeave': 'N/A'}, {'Company': 'Media Assembly', 'Industry': 'Advertising', 'MaternityLeave': 'N/A'}, {'Company': 'Castleton Commodities International', 'Industry': 'Finance: Diversified', 'MaternityLeave': 'N/A'}, {'Company': 'CARE International', 'Industry': 'Nonprofit: Humanitarian Aid Organization', 'MaternityLeave': 'N/A'}, {'Company': 'WinCo Foods', 'Industry': 'Retail: Supermarket Company', 'MaternityLeave': 'N/A'}, {'Company': 'Princess Cruises', 'Industry': 'Leisure, Travel & Tourism', 'MaternityLeave': 'N/A'}, {'Company': 'Oak Ridge National Laboratory', 'Industry': 'Government: Federal', 'MaternityLeave': 'N/A'}, {'Company': 'Black Twig Communications', 'Industry': 'Public Relations', 'MaternityLeave': 'N/A'}, {'Company': 'Midcontinent', 'Industry': 'Telecommunications', 'MaternityLeave': 'N/A'}, {'Company': 'Hanesbrands Inc', 'Industry': 'Retail: Shoes, Accessories and Apparel', 'MaternityLeave': 'N/A'}, {'Company': 'American Medical Association', 'Industry': 'Nonprofit: Medical', 'MaternityLeave': 'N/A'}, {'Company': 'SCANA Corporation', 'Industry': 'Natural Resources: Electric & Gas Utilit...', 'MaternityLeave': 'N/A'}, {'Company': 'ManTech International', 'Industry': 'Technology: B2B Tech Services', 'MaternityLeave': 'N/A'}, {'Company': 'Aspen Dental', 'Industry': 'Healthcare: Services', 'MaternityLeave': 'N/A'}, {'Company': 'BAUER Hockey, Inc', 'Industry': 'Sporting Goods', 'MaternityLeave': 'N/A'}, {'Company': '1199SEIU', 'Industry': 'Nonprofit: Healthcare', 'MaternityLeave': 'N/A'}, {'Company': 'Ex Libris Group', 'Industry': 'Technology: Software', 'MaternityLeave': 'N/A'}, {'Company': 'Clark Construction Group', 'Industry': 'Industrial: Construction Company', 'MaternityLeave': 'N/A'}, {'Company': 'BJs Wholesale Club', 'Industry': 'Retail: Discount Store', 'MaternityLeave': 'N/A'}, {'Company': 'Finning International Inc.', 'Industry': 'Industrial: Equipment Manufacturing', 'MaternityLeave': 'N/A'}]
