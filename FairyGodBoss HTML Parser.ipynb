# %%
from lxml import html
import requests

# %%
page = requests.get('https://fairygodboss.com/maternity-leave-resource-center?page=50')
tree = html.fromstring(page.content)

# %%
print(tree)
# Out:
# <Element html at 0x10f3b7228>

# %%
print(html.tostring(tree))
# Out:
# b'<html lang="en">\n<head prefix="og: http://ogp.me/ns#">\n            <!-- Global site tag (gtag.js) - Google Analytics -->\n        <script async src="https://www.googletagmanager.com/gtag/js?id=UA-52626819-1"></script>\n        <script>\n            window.dataLayer = window.dataLayer || [];\n            function gtag(){dataLayer.push(arguments);}\n            gtag(\'js\', new Date());\n\n            gtag(\'config\', \'UA-52626819-1\');\n\n        </script>\n\n    \n    \n\n    \n\n    <script type="text/javascript">\n        externalPageProps = {\n            headerProps: {"commonProps":{"role":null,"isAdmin":false,"fairygodbossUrl":"\\/","currentUrl":"\\/maternity-leave-resource-center?page=50","showTopSearchBar":true,"showSearchForm":true,"menuUrls":[{"name":"companies","url":"\\/company-overview","subMenus":null},{"name":"jobs","url":"\\/jobs\\/filter","subMenus":null},{"name":"company reviews","url":"\\/company-reviews","subtopMenus":null},{"name":"salaries","url":"\\/salary-database","subMenus":null},{"name":"maternity","url":"\\/maternity-leave","subMenus":[{"name":"maternity leave","url":"\\/maternity-leave"},{"name":"pregnancy week by week","url":"\\/pregnancy-week-by-week"}]},{"name":"work-life balance","url":"\\/work-life-balance-flexibility-guide","subMenus":null},{"name":"career advice","url":"\\/articles","subMenus":[{"name":"recent articles","url":"\\/articles"},{"name":"career topics","url":"\\/career-topics"},{"name":"podcasts","url":"community-podcasts"},{"name":"research from fairygodboss","url":"\\/research"},{"name":"research from third parties","url":"\\/third-party-research"}]},{"name":"New Today","url":"\\/community\\/feed","subMenus":null,"featuredStyling":"featured"},{"name":"top rated","url":"\\/best-companies-for-women","subMenus":[{"name":"best tech","url":"\\/best-companies-for-women-technology"},{"name":"best finance","url":"\\/best-companies-for-women-finance"},{"name":"best company CEOs","url":"\\/best-companies-for-women-gender-diversity"},{"name":"best 2018","url":"\\/best-companies-for-women-2018"}]}],"mobileMenuUrls":[{"name":"Jobs","url":"\\/jobs\\/filter"},{"name":"Advice","url":"\\/articles"},{"name":"Job Reviews","url":"\\/company-reviews"},{"name":"New Today","url":"\\/community\\/feed","featuredStyling":"featured"}]},"adminProps":{"adminLinks":[{"name":"add company","url":"\\/admins\\/add-company","authorizedRoles":["superadmin","fullEditor","sales","customerSuccess"]},{"name":"companies list","url":"\\/admins\\/companies","authorizedRoles":["superadmin","customerSuccess"]},{"name":"inactive companies","url":"\\/admins\\/inactive-companies","authorizedRoles":["superadmin"]},{"name":"user submitted data","url":"\\/admins\\/user-submitted-data","authorizedRoles":["superadmin"]},{"name":"search user","url":"\\/admins\\/user-search","authorizedRoles":["superadmin"]},{"name":"top of 2015","url":"\\/admins\\/top-companies-of2015","authorizedRoles":["superadmin","customerSuccess"]},{"name":"top of 2016","url":"\\/admins\\/top-companies-of2016","authorizedRoles":["superadmin","customerSuccess"]},{"name":"top of 2017 by quarters","url":"\\/admins\\/best-companies-by-quarter","authorizedRoles":["superadmin","customerSuccess"]},{"name":"salaries","url":"\\/admins\\/salaries","authorizedRoles":["superadmin"]},{"name":"export maternity db","url":"\\/exports\\/maternetyleave","authorizedRoles":["superadmin"]},{"name":"export maternity db(by Industry)","url":"\\/exports\\/maternetyleavebyindustry","authorizedRoles":["superadmin"]},{"name":"export maternity db(by Top Industry)","url":"\\/exports\\/maternety-leave-by-top-industry","authorizedRoles":["superadmin"]},{"name":"tags bank","url":"\\/admins\\/tags-bank","authorizedRoles":["superadmin","fullEditor"]},{"name":"benefit comments","url":"\\/admins\\/benefit-comments","authorizedRoles":["superadmin"]},{"name":"employer request","url":"\\/admins\\/employer-requests","authorizedRoles":["superadmin","sales","customerSuccess"]},{"name":"employer qu ...

# %%
rows = tree.xpath('//tr')

# %%
# Remove white space
companies = rows[0].xpath('//td/text()')

split_companies = []

for x in companies:
    split_companies.append(x.split())
    
print(split_companies)
# Out:
# [['Havas'], ['Advertising'], ['6'], ['5'], ['N/A'], ['N/A'], [], [], ['Quintiles', 'Transnational'], ['Pharmaceutical'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], [], ['Humanscale'], ['Industrial:', 'Appliances', '&', 'Furniture'], ['6'], ['9'], ['N/A'], ['N/A'], [], [], ['Sierra', 'Club'], ['Nonprofit:', 'Environmental', 'Organization'], ['6'], ['6'], ['N/A'], ['N/A'], [], [], ['Quest', 'Diagnostics'], ['Healthcare:', 'Laboratory', 'Testing'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], [], ['Mccormick'], ['Consumer', 'Packaged', 'Goods:', 'Packaged', 'Foods'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], [], ['Redfin'], ['Real', 'Estate:', 'Brokers'], ['6'], ['10'], ['N/A'], ['N/A'], [], [], ['Asurion'], ['Telecommunications'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], [], ['Creative', 'Circle'], ['Business', 'Services:', 'Staffing', '&', 'Outsourcin...'], ['6'], ['6'], ['N/A'], ['N/A'], [], [], ['Philips', 'Healthcare'], ['Healthcare:', 'Diversified'], ['6'], ['12'], ['N/A'], ['N/A'], [], [], ['NYU', 'School', 'of', 'Medicine'], ['Educational', 'Services:', 'College', '&', 'Universi...'], ['6'], ['8'], ['N/A'], ['N/A'], [], [], ['CareerBuilder'], ['Technology:', 'Consumer', 'Internet'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], [], ['Cessna', 'Aircraft', 'Company'], ['Aerospace'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], [], ['Yale', 'University'], ['Educational', 'Services:', 'College', '&', 'Universi...'], ['6'], ['26'], ['N/A'], ['N/A'], [], [], ["Claire's"], ['Retail:', 'Shoes,', 'Accessories', 'and', 'Apparel'], ['6'], ['6'], ['N/A'], ['N/A'], [], [], ['Land', "O'Lakes,", 'Inc.'], ['Consumer', 'Packaged', 'Goods:', 'Packaged', 'Foods'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], [], ["Macy's,", 'Inc.'], ['Retail:', 'Department', 'Store'], ['6'], ['6'], ['0'], ['N/A'], [], [], ['Allstate', 'Insurance', 'Group'], ['Insurance:', 'Property', '&', 'Casualty'], ['6'], ['6'], ['N/A'], ['N/A'], [], [], ['Progressive', 'Corporation'], ['Insurance:', 'Property', '&', 'Casualty'], ['6'], ['9'], ['N/A'], ['N/A'], [], [], ['UPS'], ['Transportation:', 'Couriers', '&', 'Delivery'], ['6'], ['12'], ['0'], ['N/A'], [], []]

# %%
# Each row is 8 cells long, so split by 8
separated_companies = []
one_company = []

counter = 0
for x in split_companies:
    one_company.append(x)
    counter+=1
    if counter == 8:
        separated_companies.append(one_company)
        one_company = []
        counter = 0

for x in separated_companies:
    print(x)
# Out:
# [['Havas'], ['Advertising'], ['6'], ['5'], ['N/A'], ['N/A'], [], []]
# [['Quintiles', 'Transnational'], ['Pharmaceutical'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], []]
# [['Humanscale'], ['Industrial:', 'Appliances', '&', 'Furniture'], ['6'], ['9'], ['N/A'], ['N/A'], [], []]
# [['Sierra', 'Club'], ['Nonprofit:', 'Environmental', 'Organization'], ['6'], ['6'], ['N/A'], ['N/A'], [], []]
# [['Quest', 'Diagnostics'], ['Healthcare:', 'Laboratory', 'Testing'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], []]
# [['Mccormick'], ['Consumer', 'Packaged', 'Goods:', 'Packaged', 'Foods'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], []]
# [['Redfin'], ['Real', 'Estate:', 'Brokers'], ['6'], ['10'], ['N/A'], ['N/A'], [], []]
# [['Asurion'], ['Telecommunications'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], []]
# [['Creative', 'Circle'], ['Business', 'Services:', 'Staffing', '&', 'Outsourcin...'], ['6'], ['6'], ['N/A'], ['N/A'], [], []]
# [['Philips', 'Healthcare'], ['Healthcare:', 'Diversified'], ['6'], ['12'], ['N/A'], ['N/A'], [], []]
# [['NYU', 'School', 'of', 'Medicine'], ['Educational', 'Services:', 'College', '&', 'Universi...'], ['6'], ['8'], ['N/A'], ['N/A'], [], []]
# [['CareerBuilder'], ['Technology:', 'Consumer', 'Internet'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], []]
# [['Cessna', 'Aircraft', 'Company'], ['Aerospace'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], []]
# [['Yale', 'University'], ['Educational', 'Services:', 'College', '&', 'Universi...'], ['6'], ['26'], ['N/A'], ['N/A'], [], []]
# [["Claire's"], ['Retail:', 'Shoes,', 'Accessories', 'and', 'Apparel'], ['6'], ['6'], ['N/A'], ['N/A'], [], []]
# [['Land', "O'Lakes,", 'Inc.'], ['Consumer', 'Packaged', 'Goods:', 'Packaged', 'Foods'], ['6'], ['N/A'], ['N/A'], ['N/A'], [], []]
# [["Macy's,", 'Inc.'], ['Retail:', 'Department', 'Store'], ['6'], ['6'], ['0'], ['N/A'], [], []]
# [['Allstate', 'Insurance', 'Group'], ['Insurance:', 'Property', '&', 'Casualty'], ['6'], ['6'], ['N/A'], ['N/A'], [], []]
# [['Progressive', 'Corporation'], ['Insurance:', 'Property', '&', 'Casualty'], ['6'], ['9'], ['N/A'], ['N/A'], [], []]
# [['UPS'], ['Transportation:', 'Couriers', '&', 'Delivery'], ['6'], ['12'], ['0'], ['N/A'], [], []]

# %%
def objectCompany(n): 
    return {'Company': ' '.join(n[0]), 'Industry': ' '.join(n[1]), 'MaternityLeave': n[2][0]}

# Organize elements into a dictionary
organized_companies = map(objectCompany, separated_companies)

print(list(organized_companies))
# Out:
# [{'Company': 'Havas', 'Industry': 'Advertising', 'MaternityLeave': '6'}, {'Company': 'Quintiles Transnational', 'Industry': 'Pharmaceutical', 'MaternityLeave': '6'}, {'Company': 'Humanscale', 'Industry': 'Industrial: Appliances & Furniture', 'MaternityLeave': '6'}, {'Company': 'Sierra Club', 'Industry': 'Nonprofit: Environmental Organization', 'MaternityLeave': '6'}, {'Company': 'Quest Diagnostics', 'Industry': 'Healthcare: Laboratory Testing', 'MaternityLeave': '6'}, {'Company': 'Mccormick', 'Industry': 'Consumer Packaged Goods: Packaged Foods', 'MaternityLeave': '6'}, {'Company': 'Redfin', 'Industry': 'Real Estate: Brokers', 'MaternityLeave': '6'}, {'Company': 'Asurion', 'Industry': 'Telecommunications', 'MaternityLeave': '6'}, {'Company': 'Creative Circle', 'Industry': 'Business Services: Staffing & Outsourcin...', 'MaternityLeave': '6'}, {'Company': 'Philips Healthcare', 'Industry': 'Healthcare: Diversified', 'MaternityLeave': '6'}, {'Company': 'NYU School of Medicine', 'Industry': 'Educational Services: College & Universi...', 'MaternityLeave': '6'}, {'Company': 'CareerBuilder', 'Industry': 'Technology: Consumer Internet', 'MaternityLeave': '6'}, {'Company': 'Cessna Aircraft Company', 'Industry': 'Aerospace', 'MaternityLeave': '6'}, {'Company': 'Yale University', 'Industry': 'Educational Services: College & Universi...', 'MaternityLeave': '6'}, {'Company': "Claire's", 'Industry': 'Retail: Shoes, Accessories and Apparel', 'MaternityLeave': '6'}, {'Company': "Land O'Lakes, Inc.", 'Industry': 'Consumer Packaged Goods: Packaged Foods', 'MaternityLeave': '6'}, {'Company': "Macy's, Inc.", 'Industry': 'Retail: Department Store', 'MaternityLeave': '6'}, {'Company': 'Allstate Insurance Group', 'Industry': 'Insurance: Property & Casualty', 'MaternityLeave': '6'}, {'Company': 'Progressive Corporation', 'Industry': 'Insurance: Property & Casualty', 'MaternityLeave': '6'}, {'Company': 'UPS', 'Industry': 'Transportation: Couriers & Delivery', 'MaternityLeave': '6'}]
